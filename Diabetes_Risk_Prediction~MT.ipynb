# %% [markdown]
# <a href="https://colab.research.google.com/github/joysosanya/Diabetes_Risk_Prediction/blob/main/Diabetes_Risk_Prediction~MT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJECT TITLE:
# EARLY DIABETES RISK PREDICTION ANALYSIS**

# %% [markdown]
# **Diabetes** is a condition that happens when your blood sugar (glucose) is too high. It develops when your pancreas doesn’t make enough insulin or any at all, or when your body isn’t responding to the effects of insulin properly. Diabetes affects people of all ages. Most forms of diabetes are chronic (lifelong), and all forms are manageable with medications and/or lifestyle changes.

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png](data:image/png;base64,...)...)![image.png](data:image/png;base64,...)

# %% [markdown]
# **AIM:** This project aims to predict early diabetes risk with the use of Machine Learning

# %% [markdown]
# **Dataset Source**:Kaggle

# %% [markdown]
# **Attributes Overview**
#
# **Age**: This attribute represents the age of the patient. It is a numerical value indicating how old the patient is, typically measured in years. Age can be a significant factor in the development and prediction of diabetes, as the risk generally increases with age.
#
# **Gender**: This categorical attribute indicates the gender of the patient. It usually has two possible values: 'Male' or 'Female'. Gender can influence the prevalence and progression of diabetes and may interact with other risk factors.
#
# **Polyuria:** This binary attribute indicates whether the patient experiences excessive urination. Polyuria is a common symptom of diabetes and is often used as a predictive factor.
#
# **Polydipsia:** This binary attribute indicates whether the patient experiences excessive thirst. Polydipsia is another common symptom of diabetes and is closely related to polyuria.
#
# **Sudden Weight Loss:** This binary attribute indicates whether the patient has experienced sudden weight loss. Unexplained weight loss can be an early sign of diabetes, particularly type 1 diabetes.
#
# **Weakness:** This binary attribute indicates whether the patient feels general weakness. Fatigue and weakness can be symptoms of diabetes due to the body's inability to use glucose effectively.
#
# **Polyphagia:** This binary attribute indicates whether the patient experiences excessive hunger. Polyphagia is a symptom where the patient feels the need to eat frequently and is often associated with diabetes.
#
# **Genital Thrush:** This binary attribute indicates whether the patient has had genital thrush. Recurrent infections like genital thrush can be a sign of diabetes due to high blood sugar levels that create a favorable environment for yeast infections.
#
# **Visual Blurring:** This binary attribute indicates whether the patient experiences visual blurring. Diabetes can affect vision due to fluctuations in blood sugar levels, leading to temporary or permanent visual disturbances.
#
# **Itching:** This binary attribute indicates whether the patient experiences itching. Itchy skin can be a symptom of diabetes due to dry skin or poor blood circulation.
#
# **Irritability:** This binary attribute indicates whether the patient feels irritable. Mood changes, including irritability, can be associated with diabetes due to fluctuating blood sugar levels.
#
# **Delayed Healing:** This binary attribute indicates whether the patient has noticed delayed healing of wounds. Slow healing can be a sign of diabetes as high blood sugar levels can impair the healing process.
#
# **Partial Paresis:** This binary attribute indicates whether the patient experiences partial paresis, which is partial paralysis or muscle weakness. Diabetes can cause nerve damage, leading to such symptoms.
#
# **Muscle Stiffness:** This binary attribute indicates whether the patient experiences muscle stiffness. Diabetes can cause muscle stiffness due to changes in metabolism and blood flow.
#
# **Alopecia:** This binary attribute indicates whether the patient has experienced hair loss (alopecia). Diabetes can affect hair growth due to hormonal imbalances and poor blood circulation.
#
# **Obesity:** This binary attribute indicates whether the patient is obese. Obesity is a significant risk factor for diabetes, particularly type 2 diabetes.
#
# **Class:** This target attribute indicates whether the patient is classified as having early-stage diabetes. It is usually a binary attribute where a value indicates either the presence or absence of diabetes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# The code below displays the loaded DataFrame, it will print the first few rows and columns of the DataFrame, giving a glimpse of the structure and content of the data.
# It allows for inspection of data before performing further exploratory or statistical analysis.

# %%
df = pd.read_csv('/content/diabetes_data_upload.csv')
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %% [markdown]
# The code below provides a summary of the DataFrame, offering insights into the following: Number of entries (rows),Column names and data types, Non-null counts and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
# ...

# %%
df.value_counts()
# Out:
# Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  Polyphagia  Genital thrush  visual blurring  Itching  Irritability  delayed healing  partial paresis  muscle stiffness  Alopecia  Obesity  class
# 30   Male    No        No          No                  No        No          No              No               No       No            No               No               No                No        No       Negative    16
# 46   Male    No        No          No                  Yes       No          No              No               Yes      No            Yes              No               No                Yes       No       Negative     7
# 53   Male    No        No          No                  Yes       Yes         No              Yes              Yes      No            Yes              Yes              Yes               Yes       No       Negative     7
# ...

# %%
df['class'].value_counts().plot(kind='bar', color=['salmon', 'lightblue'], xlabel='Has Diabetes');

# %% [markdown]
# There are significantly more positive cases of diabetes than negative cases in this dataset. This suggests that a large portion of the population tested has diabetes, with a higher proportion of positive diagnoses compared to negative ones.

# %%
df['Gender'].value_counts().plot(kind='bar', color=['salmon', 'lightblue']);

# %%
pd.crosstab(df['class'], df.Gender).plot(kind='bar',
                                                               figsize=(10, 6),
                                                               color=['salmon', 'lightblue'])
plt.title('Diabetes ratio between gender')
plt.xlabel('Has Diabetes')
plt.ylabel('number of patient');

# %% [markdown]
# The chart above shows that:
#
# More males are represented in the negative group, meaning a larger proportion of males tested negative for diabetes.
#
# More females are represented in the positive group, indicating a higher incidence of diabetes among females in this dataset.

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'class'],
#       dtype='object')

# %%
columns = df.drop(['Age', 'class'], axis=1).columns

fig, ax = plt.subplots(8 ,2, figsize=(20, 30))
fig.subplots_adjust(hspace=0.5)
r = 0
c = 0
for col in columns:
    sns.scatterplot(df, x=df.Age, y=df['class'], hue=col, ax=ax[c, r])
    ax[c, r].set_title(f'Distribution of {col} by age and diagnosis')
    ax[c, r].legend(loc='center')
    c += 1
    if c > 7:
        r += 1
        c = 0

# %%
categories = ['Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
              'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
              'Itching', 'Irritability', 'delayed healing', 'partial paresis',
              'muscle stiffness', 'Alopecia', 'Obesity', 'class']

for category in categories:
    df.loc[:, category +' factorised'] = pd.factorize(df[category])[0]

# %%
corr_matrix = df.drop(categories,axis=1).corr()
fig, ax = plt.subplots(figsize=(15, 10))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt='.2f',
                 cmap='YlGnBu')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (17.5, -0.5)

# %% [markdown]
# Polyuria and Polydipsia show a strong negative correlation (-0.60), indicating an inverse relationship between these two symptoms in your dataset, which could be an important observation specific to your analysis.
#
# Polydipsia has the strongest positive relationship with the class (0.65), while Polyuria has the strongest negative relationship (-0.67).
#
# Other factors, like Weakness, Partial Paresis, and Muscle Stiffness, have moderate correlations, suggesting potential symptom clusters.

# %% [markdown]
# Factorization is crucial for machine learning models, which typically require numeric inputs. By converting categorical data into numeric form, the dataset becomes ready for model training and analysis.

# %%
df_clean = df
# Creates a copy of the original DataFrame df and assigns it to df_clean. This ensures that any changes made during cleaning won’t affect the original dataset.
df_clean['Gender'] = pd.factorize(df_clean['Gender'])[0]
# The pd.factorize() function encodes the categorical data into integer values, where each unique category is assigned a unique integer.
# pd.factorize(column)[0] will return the integer codes for the categorical values in the specified column.
# The next series of lines converts categorical columns (Gender, Polyuria, Polydipsia, etc.) to numeric representations:
df_clean['Polyuria'] = pd.factorize(df_clean['Polyuria'])[0]
df_clean['Polydipsia'] = pd.factorize(df_clean['Polydipsia'])[0]
df_clean['sudden weight loss'] = pd.factorize(df_clean['sudden weight loss'])[0]
df_clean['weakness'] = pd.factorize(df_clean['weakness'])[0]
df_clean['Polyphagia'] = pd.factorize(df_clean['Polyphagia'])[0]
df_clean['visual blurring'] = pd.factorize(df_clean['visual blurring'])[0]
df_clean['Itching'] = pd.factorize(df_clean['Itching'])[0]
df_clean['delayed healing'] = pd.factorize(df_clean['delayed healing'])[0]
df_clean['partial paresis'] = pd.factorize(df_clean['partial paresis'])[0]
df_clean['muscle stiffness'] = pd.factorize(df_clean['muscle stiffness'])[0]
df_clean['Alopecia'] = pd.factorize(df_clean['Alopecia'])[0]
df_clean['class'] = pd.factorize(df_clean['class'])[0]

# %% [markdown]
# The next lines of code helps to remove unnecessary or irrelevant features from the dataset, which will help in focusing on the most relevant variables for analysis or modeling.

# %%
df_clean = df
df_clean = df_clean.drop(['Genital thrush','Irritability','Obesity'],axis=1)
df_clean.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'visual blurring', 'Itching',
#        'delayed healing', 'partial paresis', 'muscle stiffness', 'Alopecia',
#        'class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    int64
#  2   Polyuria            520 non-null    int64
#  3   Polydipsia          520 non-null    int64
#  4   sudden weight loss  520 non-null    int64
#  5   weakness            520 non-null    int64
#  6   Polyphagia          520 non-null    int64
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    int64
#  9   Itching             520 non-null    int64
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    int64
#  12  partial paresis     520 non-null    int64
#  13  muscle stiffness    520 non-null    int64
#  14  Alopecia            520 non-null    int64
#  15  Obesity             520 non-null    object
# ...

# %% [markdown]
# Lines of code below splits the cleaned DataFrame (df_clean) into two separate sets: features (X) and target labels (y).
#
# X = df_clean.drop('class', axis=1):
# This line creates a new DataFrame X that contains all columns from df_clean except the 'class' column.
# drop('class', axis=1): Removes the column 'class', which is typically the target variable or label (the outcome you're predicting), and retains the remaining columns as features.
# X will store the features (i.e., independent variables) used for prediction.
#
# y = df_clean['class']:
# This line creates a series y that contains only the 'class' column from df_clean.
# y is the target variable or label, often representing the outcome you're trying to predict (e.g., whether a patient has diabetes or not).

# %%
X = df_clean.drop('class' , axis = 1 )
y = df_clean['class']

# %%
X
# Out:
#      Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 0     40       0         0           0                   0         0
# 1     58       0         0           1                   0         0
# 2     41       0         1           1                   0         0
# 3     45       0         0           1                   1         0
# 4     60       0         1           0                   1         0
# ..   ...     ...       ...         ...                 ...       ...
# 515   39       1         1           0                   1         1
# 516   48       1         1           0                   1         0
# 517   58       1         1           0                   1         0
# 518   32       1         0           1                   0         0
# 519   42       0         0           1                   0         1
#
#      Polyphagia  visual blurring  Itching  delayed healing  partial paresis  \
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 515    0
# 516    0
# 517    0
# 518    1
# 519    1
# Name: class, Length: 520, dtype: int64

# %% [markdown]
# **Train and Test**
# Training set (X_train, y_train): Used to train the machine learning model, where the model learns patterns from the data.
# Testing set (X_test, y_test): Used to evaluate the model's performance on unseen data to determine how well it generalizes.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y , test_size = 0.2 ,random_state = 0)

# %% [markdown]
# **Normalization** is used to bring all the features to the same scale, especially for machine learning algorithms that are sensitive to the magnitude of input data (e.g., gradient-based methods like logistic regression, neural networks, and support vector machines).
# This prevents features with larger scales from dominating the model during training.

# %%
from sklearn.preprocessing import MinMaxScaler
scl = MinMaxScaler().fit(X_train)
X_train_norm = scl.transform(X_train)
X_test_norm = scl.transform(X_test)

# %% [markdown]
# **SVC Test:**
# The main purpose of SVC is to provide an effective classification mechanism by finding the optimal decision boundary between classes, while being flexible enough to handle both linear and non-linear data, and robust against noise and outliers.

# %%
from sklearn.svm import SVC
model = SVC(C=8, random_state=0)
model.fit(X_train_norm, y_train)
y_predict = model.predict(X_test_norm)
sum(y_test == y_predict) / len(y_test)
# Out:
# 0.9903846153846154

# %% [markdown]
# Train

# %%
from sklearn.model_selection import cross_val_predict
model = SVC(C=3, random_state=0)
y_predict = cross_val_predict(model, X_train_norm, y_train, cv=10)
sum(y_train == y_predict) / len(y_train)
# Out:
# 0.9735576923076923

# %% [markdown]
# **Linear SVC:** Linear Support Vector Classification (Linear SVC) is a variant of Support Vector Classification (SVC) specifically designed for linear decision boundaries

# %%
from sklearn.svm import LinearSVC

# %% [markdown]
# Train Dataset

# %%
from sklearn.model_selection import cross_val_predict
model = LinearSVC()
y_predict = cross_val_predict(model, X_train_norm, y_train, cv=10)
lin_svc_train_acc = sum(y_train == y_predict) / len(y_train)
lin_svc_train_acc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# ...

# %% [markdown]
# Test Dataset

# %%
model = LinearSVC()
model.fit(X_train_norm, y_train)
y_predict = model.predict(X_test_norm)
lin_svc_test_acc = sum(y_test == y_predict) / len(y_test)
lin_svc_test_acc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 0.9423076923076923

# %% [markdown]
# **Random Forest Classifier:** The Random Forest Classifier is a robust and flexible model that can handle a variety of classification tasks with high accuracy. Its ensemble nature and feature randomness help in improving generalization and reducing overfitting

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Test

# %%
from sklearn.model_selection import cross_val_predict
model = RandomForestClassifier()
y_predict = cross_val_predict(model, X_train_norm, y_train, cv=10)
lin_svc_train_acc = sum(y_train == y_predict) / len(y_train)
lin_svc_train_acc
# Out:
# 0.9759615384615384

# %%
model = RandomForestClassifier()
model.fit(X_train_norm, y_train)
y_predict = model.predict(X_test_norm)
rand_fore_test_acc = sum(y_test == y_predict) / len(y_test)
rand_fore_test_acc
# Out:
# 1.0

# %% [markdown]
# XGBClassifier()

# %%
from xgboost import XGBClassifier

# %% [markdown]
# Train

# %%
from sklearn.model_selection import cross_val_predict
model = XGBClassifier()
y_predict = cross_val_predict(model, X_train_norm, y_train, cv=10)
lin_svc_train_acc = sum(y_train == y_predict) / len(y_train)
lin_svc_train_acc
# Out:
# 0.9639423076923077

# %% [markdown]
# Test

# %%
model = XGBClassifier()
model.fit(X_train_norm, y_train)
y_predict = model.predict(X_test_norm)
rand_fore_test_acc = sum(y_test == y_predict) / len(y_test)
rand_fore_test_acc
# Out:
# 0.9903846153846154

# %% [markdown]
# GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# Train

# %%
from sklearn.model_selection import cross_val_predict
model = GaussianNB()
y_predict = cross_val_predict(model, X_train_norm, y_train, cv=10)
lin_svc_train_acc = sum(y_train == y_predict) / len(y_train)
lin_svc_train_acc
# Out:
# 0.8990384615384616

# %% [markdown]
# Test

# %%
model = GaussianNB()
model.fit(X_train_norm, y_train)
y_predict = model.predict(X_test_norm)
rand_fore_test_acc = sum(y_test == y_predict) / len(y_test)
rand_fore_test_acc
# Out:
# 0.9423076923076923

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Train

# %%
from sklearn.model_selection import cross_val_predict
model = LogisticRegression()
y_predict = cross_val_predict(model, X_train_norm, y_train, cv=10)
lin_svc_train_acc = sum(y_train == y_predict) / len(y_train)
lin_svc_train_acc
# Out:
# 0.9038461538461539

# %% [markdown]
# Test

# %%
model = LogisticRegression()
model.fit(X_train_norm, y_train)
y_predict = model.predict(X_test_norm)
rand_fore_test_acc = sum(y_test == y_predict) / len(y_test)
rand_fore_test_acc
# Out:
# 0.9230769230769231

# %% [markdown]
# The main objective of this project is to predict whether a patient has diabetes based on medical data using various machine learning models. Several models were tested, and their performance was evaluated on both training and test datasets. The goal is to identify the most accurate and reliable model for predicting diabetes.
#
# Models Evaluated:
# Linear Support Vector Classifier (LinearSVC)
# Random Forest Classifier
# XGBoost Classifier
# Gaussian Naive Bayes
# Logistic Regression

# %% [markdown]
# **Model Results:**
#
# **Linear Support Vector Classifier (LinearSVC)**
#
# Test Accuracy: 94.23%
# LinearSVC showed a strong performance on the test dataset, with a high accuracy of 94.23%. However, it displayed a warning due to the default dual parameter, which could be adjusted in future implementations to optimize performance.
#
# **Random Forest Classifier**
#
# Training Accuracy: 97.60%
# Test Accuracy: 100%
# The Random Forest Classifier was the top performer with a perfect accuracy of 100% on the test set. Its ensemble nature and ability to handle complex datasets make it a highly reliable model for this classification task. The high test accuracy indicates no overfitting, and the model generalizes well.
#
# **XGBoost Classifier**
#
# Training Accuracy: 96.39%
# Test Accuracy: 99.04%
# XGBoost also performed well, achieving an impressive test accuracy of 99.04%. This model is known for its efficiency and effectiveness in handling large datasets. Its training accuracy of 96.39% suggests a solid generalization capability.
#
# **Gaussian Naive Bayes (GaussianNB)**
#
# Training Accuracy: 89.90%
# Test Accuracy: 94.23%
# GaussianNB showed relatively lower accuracy compared to the other models, with a training accuracy of 89.90% and a test accuracy of 94.23%. While it’s simple and fast, this model might not be the best choice for this particular task given the presence of more powerful alternatives.
#
# **Logistic Regression**
#
# Training Accuracy: 90.38%
# Test Accuracy: 92.31%
# Logistic Regression is a strong baseline model and achieved a decent test accuracy of 92.31%. It’s easy to interpret and useful for binary classification, but its accuracy falls short compared to Random Forest and XGBoost in this case.

# %% [markdown]
# **Conclusion:**
#
# The Random Forest Classifier is the most accurate model, achieving a perfect 100% accuracy on the test dataset. It is recommended for predicting whether a patient has diabetes, as it generalizes well without overfitting.
#
# XGBoost is also a strong contender with near-perfect performance (99.04%) and can be considered if computational efficiency is important.
#
# Gaussian Naive Bayes and Logistic Regression performed adequately, but they were outperformed by the more complex models.
#
# In future iterations of the project, hyperparameter tuning and additional data preprocessing could be explored to improve the performance of other models.
